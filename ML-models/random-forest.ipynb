# %%
#import dependencies
import pandas as pd
import sqlite3

#display all columns in dfs
pd.set_option('display.max_columns', None)

# %%
#connect to SQLite db
conn = sqlite3.connect('../Data-and-DBs/pokedex.db')

# %%
#call all entries from the gens_1_to_6 table in the db
training_df = pd.read_sql('SELECT * FROM gens_1_to_6', conn)
training_df.head()
# Out:
#    NUMBER  CODE  SERIAL           NAME  TYPE1   TYPE2  COLOR   ABILITY1  \
# 0       1     1      11      Bulbasaur  Grass  Poison  Green   Overgrow
# 1       2     1      21        Ivysaur  Grass  Poison  Green   Overgrow
# 2       3     1      31       Venusaur  Grass  Poison  Green   Overgrow
# 3       3     2      32  Mega Venusaur  Grass  Poison  Green  Thick Fat
# 4       4     1      41     Charmander   Fire    None    Red      Blaze
#
#   ABILITY2 ABILITY_HIDDEN  GENERATION  LEGENDARY_FLAG  HEIGHT  WEIGHT  HP  \
# 0     None    Chrolophyll           1               0     0.7     6.9  45
# 1     None    Chrolophyll           1               0     1.0    13.0  60
# 2     None    Chrolophyll           1               0     2.0   100.0  80
# 3     None           None           1               0     2.4   155.5  80
# 4     None    Solar Power           1               0     0.6     8.5  39
#
#    ATK  DEF  SP_ATK  SP_DEF  SPD  TOTAL  CAPTURE_RATE
# ...

# %%
#pull necessary info from the gens_1_to_6 training df to create training data
X_train = training_df[['TYPE1', 'TYPE2', 'ABILITY1', 'ABILITY2', 'ABILITY_HIDDEN', 'HP', 'ATK', 'DEF', 
                 'SP_ATK', 'SP_DEF', 'SPD', 'TOTAL', 'CAPTURE_RATE']]
y_train = training_df['LEGENDARY_FLAG']
#double-check shapes of X and y match
print(X_train.shape, y_train.shape)
# Out:
# (817, 13) (817,)

# %%
#call all entries from the gen7 and gen_8 table in the db
test_df_1 = pd.read_sql('SELECT * FROM gen_7', conn)
test_df_2 = pd.read_sql('SELECT * FROM gen_8', conn)

# %%
#pull necessary info from the gen_7 and gen_8 testing dfs to create test data
X_test_1 = test_df_1[['TYPE1', 'TYPE2', 'ABILITY1', 'ABILITY2', 'ABILITY_HIDDEN', 'HP', 'ATK', 'DEF', 
                 'SP_ATK', 'SP_DEF', 'SPD', 'TOTAL', 'CAPTURE_RATE']]
y_test_1 = test_df_1['LEGENDARY_FLAG']

X_test_2 = test_df_2[['TYPE1', 'TYPE2', 'ABILITY1', 'ABILITY2', 'ABILITY_HIDDEN', 'HP', 'ATK', 'DEF', 
                 'SP_ATK', 'SP_DEF', 'SPD', 'TOTAL', 'CAPTURE_RATE']]
y_test_2 = test_df_2['LEGENDARY_FLAG']

#double-check shapes of X and y match
print(X_test_1.shape, y_test_1.shape)
print(X_test_2.shape, y_test_2.shape)
# Out:
# (118, 13) (118,)
# (117, 13) (117,)

# %%
#import random forest test
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
#fit to the training data
rf = rf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-ee5ffbb817f0> in <module>
#       1 #import random forest test
# ----> 2 from sklearn.ensemble import RandomForestClassifier
#       3 rf = RandomForestClassifier(n_estimators=200)
#       4 #fit to the training data
#       5 rf = rf.fit(X_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\__init__.py in <module>
#      78     from . import _distributor_init  # noqa: F401
#      79     from . import __check_build  # noqa: F401
# ---> 80     from .base import clone
#      81     from .utils._show_versions import show_versions
#      82
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in <module>
#      19 from . import __version__
#      20 from ._config import get_config
# ---> 21 from .utils import _IS_32BIT
#      22 from .utils.validation import check_X_y
# ...
